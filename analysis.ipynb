# %% [markdown]
# # All Graphs

# %%
import pandas as pd
import matplotlib.pyplot as plt

# data = pd.read_csv('data/iterative-res.csv', skipinitialspace=True)
data = pd.read_csv('data/res.csv', skipinitialspace=True)

data['command'] = data['command'].astype(str)
commands = sorted(data['command'].unique())

fig, ax = plt.subplots(figsize=(10,6))

cmdMap = {
    '1' : "Date & Time",
    '2' : "Uptime",
    '3' : "Memory Use",
    '4' : "Netstat",
    '5' : "Current Users",
    '6' : "Running Processes"
}

colorMap = {
    '1' : "blue",
    '2' : "orange",
    '3' : "green",
    '4' : "red",
    '5' : "purple",
    '6' : "brown"
}

for command in commands:
    command_data = data[data['command'] == command]
    command_data = command_data.sort_values(by="numThreads")
    ax.plot(
        command_data['numThreads'],
        command_data['averageTime'],
        label=cmdMap[command],
        marker='o',
        color=colorMap[command]
    )

ax.set_title('Average time vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')

ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Date & Time

# %%
fig, ax = plt.subplots(figsize=(10,6))

command_data = data[data['command'] == '1']

command_data = command_data.sort_values(by="numThreads")

ax.plot(
    command_data['numThreads'],
    command_data['averageTime'],
    label=cmdMap['1'],
    marker='o',
    color=colorMap['1']
)

ax.set_title('Date & Time: Average Runtime vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')

ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Uptime

# %%
fig, ax = plt.subplots(figsize=(10,6))

command_data = data[data['command'] == '2']

command_data = command_data.sort_values(by="numThreads")

ax.plot(
    command_data['numThreads'],
    command_data['averageTime'],
    label=cmdMap['2'],
    marker='o',
    color=colorMap['2']
)

ax.set_title('Uptime: Average Runtime vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')

ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Memory Use

# %%
fig, ax = plt.subplots(figsize=(10,6))

command_data = data[data['command'] == '3']

command_data = command_data.sort_values(by="numThreads")

ax.plot(
    command_data['numThreads'],
    command_data['averageTime'],
    label=cmdMap['3'],
    marker='o',
    color=colorMap['3']

)

ax.set_title('Memory Use: Average Runtime vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')

ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Netstat

# %%
fig, ax = plt.subplots(figsize=(10,6))

command_data = data[data['command'] == '4']

command_data = command_data.sort_values(by="numThreads")

ax.plot(
    command_data['numThreads'],
    command_data['averageTime'],
    label=cmdMap['4'],
    marker='o',
    color=colorMap['4']
)

ax.set_title('Netstat: Average Runtime vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')


ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Current Users

# %%
fig, ax = plt.subplots(figsize=(10,6))

command_data = data[data['command'] == '5']

command_data = command_data.sort_values(by="numThreads")

ax.plot(
    command_data['numThreads'],
    command_data['averageTime'],
    label=cmdMap['5'],
    marker='o',
    color=colorMap['5']
)

ax.set_title('Current Users: Average Runtime vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')


ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Running Processes

# %%
fig, ax = plt.subplots(figsize=(10,6))

command_data = data[data['command'] == '6']

command_data = command_data.sort_values(by="numThreads")

ax.plot(
    command_data['numThreads'],
    command_data['averageTime'],
    label=cmdMap['6'],
    marker='o',
    color=colorMap['6']
)

ax.set_title('Running Processes: Average Runtime vs. Thread Count')
ax.set_xlabel('Thread Count')
ax.set_ylabel('Average Time (seconds)')


ax.legend(title="Command")
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

plt.show()
